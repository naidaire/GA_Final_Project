# %% [markdown]
# # Import & Review Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
import seaborn as sns

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
file = './data/trumptweets_all.csv'

# %%
trumptweets = pd.read_csv(file, encoding = 'latin1',
                          index_col='created_at')

# %%
trumptweets.head()
# Out:
#                               source  \
# created_at
# 12/28/2012 21:23  Twitter Web Client
# 12/28/2012 21:22  Twitter Web Client
# 12/28/2012 21:20  Twitter Web Client
# 12/28/2012 21:19  Twitter Web Client
# 12/28/2012 21:13  Twitter Web Client
#
#                                                                text  \
# created_at
# 12/28/2012 21:23  @opus_6  Thanks it's a wonderful place to be--...
# 12/28/2012 21:22  @Earther57  Sounds nice--and thanks. Happy New...
# 12/28/2012 21:20  You have to set higher and higher goals.  You...
# 12/28/2012 21:19  Visiting New York City?  Make sure to skate in...
# 12/28/2012 21:13  @sixelA1984 @LilJon @CelebApprentice  Raising ...
#
#                   retweet_count  favorite_count  is_retweet  \
# created_at
# 12/28/2012 21:23              1               1       False
# 12/28/2012 21:22              3               2       False
# 12/28/2012 21:20           1038             458       False
# 12/28/2012 21:19             72              38       False
# 12/28/2012 21:13              2               1       False
#
#                               id_str
# created_at
# 12/28/2012 21:23  284771680499408896
# 12/28/2012 21:22  284771320418410496
# 12/28/2012 21:20  284770791126601728
# 12/28/2012 21:19  284770536779829248
# 12/28/2012 21:13  284769064302280704

# %%
trumptweets.shape
# Out:
# (32959, 6)

# %% [markdown]
# # Prepare Data for Analysis

# %%
#Cast index of created_at dates to datetime format

trumptweets.index = pd.to_datetime(trumptweets.index)

# %%
#add new column for HOUR when the tweet occurred

trumptweets.loc[:, 'tweet_hour'] = trumptweets.index.hour

# %%
trumptweets.loc[:, 'source'].value_counts()
# Out:
# Twitter for Android         14545
# Twitter Web Client          11978
# Twitter for iPhone           4825
# TweetDeck                     480
# TwitLonger Beta               405
# Instagram                     133
# Media Studio                  130
# Facebook                      105
# Twitter for BlackBerry         97
# Twitter Ads                    97
# Mobile Web (M5)                56
# Twitter for iPad               51
# Twitlonger                     23
# Vine - Make a Scene            10
# Twitter QandA                  10
# Periscope                       7
# Neatly For BlackBerry 10        5
# Twitter Mirror for iPad         1
# Twitter for Websites            1
# Name: source, dtype: int64

# %%
# Convert Source column to dummy variables

#map source twitter for the 19 source values into integers

trumptweets.loc[:, 'source_num'] = trumptweets.loc[:,'source'].map({'Twitter for Android':0,
                                                                    'Twitter Web Client':1,
                                                                    'Twitter for iPhone':2,
                                                                    'TweetDeck':3,
                                                                    'TwitLonger Beta':4,
                                                                    'Instagram':5,
                                                                    'Media Studio':6,
                                                                    'Facebook':7,
                                                                    'Twitter for BlackBerry':8,
                                                                    'Twitter Ads':9,
                                                                    'Mobile Web (M5)':10,
                                                                    'Twitter for iPad':11,
                                                                    'Twitlonger':12,
                                                                    'Twitter QandA':13,
                                                                    'Vine - Make a Scene':14,
                                                                    'Periscope':15,
                                                                    'Neatly For BlackBerry 10':16,
                                                                    'Twitter Mirror for iPad':17,
                                                                    'Twitter for Websites':18})

# %%
trumptweets
# Out:
#                                  source  \
# created_at
# 2012-12-28 21:23:00  Twitter Web Client
# 2012-12-28 21:22:00  Twitter Web Client
# 2012-12-28 21:20:00  Twitter Web Client
# 2012-12-28 21:19:00  Twitter Web Client
# 2012-12-28 21:13:00  Twitter Web Client
# 2012-12-28 21:02:00  Twitter Web Client
# 2012-12-28 20:45:00  Twitter Web Client
# 2012-12-28 20:41:00  Twitter Web Client
# 2012-12-28 20:36:00  Twitter Web Client
# 2012-12-28 20:23:00  Twitter Web Client
# 2012-12-28 20:09:00  Twitter Web Client
# 2012-12-28 19:50:00  Twitter Web Client
# 2012-12-28 19:45:00  Twitter Web Client
# 2012-12-28 19:24:00  Twitter Web Client
# 2012-12-28 19:01:00  Twitter Web Client
# 2012-12-28 18:54:00  Twitter Web Client
# 2012-12-28 18:40:00  Twitter Web Client
# 2012-12-28 18:28:00  Twitter Web Client
# 2012-12-28 18:13:00  Twitter Web Client
# 2012-12-28 17:52:00  Twitter Web Client
# 2012-12-28 17:48:00  Twitter Web Client
# 2012-12-28 16:30:00  Twitter Web Client
# 2012-12-28 16:13:00  Twitter Web Client
# 2012-12-28 16:11:00  Twitter Web Client
# 2012-12-28 16:09:00  Twitter Web Client
# 2012-12-28 16:08:00  Twitter Web Client
# 2012-12-28 16:04:00  Twitter Web Client
# 2012-12-28 16:03:00  Twitter Web Client
# 2012-12-28 16:02:00  Twitter Web Client
# 2012-12-28 16:01:00  Twitter Web Client
# ...                                 ...
# 2011-03-07 19:01:00  Twitter Web Client
# 2011-03-04 15:12:00  Twitter Web Client
# 2011-03-03 14:52:00  Twitter Web Client
# 2011-03-02 15:47:00  Twitter Web Client
# 2011-03-02 00:02:00  Twitter Web Client
# 2011-02-28 21:53:00  Twitter Web Client
# 2011-02-28 17:42:00  Twitter Web Client
# 2011-02-28 17:36:00  Twitter Web Client
# 2011-02-23 21:43:00  Twitter Web Client
# 2011-02-22 19:32:00  Twitter Web Client
# 2011-02-18 15:13:00  Twitter Web Client
# 2011-02-17 22:48:00  Twitter Web Client
# 2011-02-17 16:06:00  Twitter Web Client
# 2011-02-16 20:59:00  Twitter Web Client
# 2011-02-16 20:55:00  Twitter Web Client
# 2011-02-15 18:56:00  Twitter Web Client
# 2011-02-15 14:38:00  Twitter Web Client
# 2011-02-15 14:27:00  Twitter Web Client
# 2011-02-11 14:50:00  Twitter Web Client
# 2011-02-10 18:29:00  Twitter Web Client
# 2011-02-07 14:15:00  Twitter Web Client
# 2011-01-31 14:25:00  Twitter Web Client
# 2011-01-31 14:04:00  Twitter Web Client
# 2011-01-27 21:14:00  Twitter Web Client
# 2011-01-27 21:13:00  Twitter Web Client
# 2011-01-21 18:25:00  Twitter Web Client
# 2011-01-21 17:20:00  Twitter Web Client
# 2011-01-13 16:14:00  Twitter Web Client
# 2011-01-12 19:35:00  Twitter Web Client
# 2011-01-12 15:28:00  Twitter Web Client
#
#                                                                   text  \
# created_at
# 2012-12-28 21:23:00  @opus_6  Thanks it's a wonderful place to be--...
# 2012-12-28 21:22:00  @Earther57  Sounds nice--and thanks. Happy New...
# 2012-12-28 21:20:00  You have to set higher and higher goals.  You...
# 2012-12-28 21:19:00  Visiting New York City?  Make sure to skate in...
# 2012-12-28 21:13:00  @sixelA1984 @LilJon @CelebApprentice  Raising ...
# 2012-12-28 21:02:00  Leverage: dont make deals without it.  The...
# 2012-12-28 20:45:00  Raising the capital gains tax in this fragile ...
# 2012-12-28 20:41:00  @phillykayman The Art of the Deal is a good st...
# 2012-12-28 20:36:00                    @WandaSalley  Thanks--have fun!
# 2012-12-28 20:23:00  I always enjoy watching young entrepreneurs en...
# 2012-12-28 20:09:00  Once again Obama is going to lose on another p...
# 2012-12-28 19:50:00  Obama wants taxes to go up so he can take cred...
# 2012-12-28 19:45:00                       @Nicholas_Lipton  March 3rd.
# 2012-12-28 19:24:00  Any deal completed before the fiscal curb must...
# 2012-12-28 19:01:00  The Republicans once again hold all the cards ...
# 2012-12-28 18:54:00                @Limka11 @Jess_Wiliem98  Thank you.
# 2012-12-28 18:40:00  My @gretawire interview re: how the debt ceili...
# 2012-12-28 18:28:00  Spolier alert
# the record setting 13th season o...
# 2012-12-28 18:13:00  Donald Trump on Fiscal Cliff and Obama http:...
# 2012-12-28 17:52:00  "True courage is being afraid and going ahead ...
# 2012-12-28 17:48:00  Sorry to hear of yesterdays passing of Genera...
# 2012-12-28 16:30:00  @ptlyons Thank you. Wishing you and yours a Ha...
# 2012-12-28 16:13:00                            @mattmaddix  Good luck.
# 2012-12-28 16:11:00  @MikeyAdamsWEEI  Thanks--and Happy New Year to...
# 2012-12-28 16:09:00                  @lin0729  Yes--he is a great guy!
# 2012-12-28 16:08:00                        @KryssiTooCool18 Thank you.
# 2012-12-28 16:04:00                                       @MjTis  Yes!
# 2012-12-28 16:03:00      @JesseTMaguire @alkapranos Even more--thanks.
# 2012-12-28 16:02:00                                   @mayorgas  Good.
# 2012-12-28 16:01:00                         @NYClights420   I hope so!
# ...                                                                ...
# 2011-03-07 19:01:00  Mark it on your calendar: Comedy Central Roast...
# 2011-03-04 15:12:00  Watch You've Got Donald Trump at http://aol.it...
# 2011-03-03 14:52:00  I appeared on David Letterman last night. And ...
# 2011-03-02 15:47:00  I was on the TODAY Show this morning and then ...
# 2011-03-02 00:02:00  I answered some of your questions in today's v...
# 2011-02-28 21:53:00  Check out today's video blog http://bit.ly/g75...
# 2011-02-28 17:42:00  ALso coming up: The Celebrity Apprentice retur...
# 2011-02-28 17:36:00  Coming up in March: The "Comedy Central Roast ...
# 2011-02-23 21:43:00  I answered your questions in today's video... ...
# 2011-02-22 19:32:00  Check out today's From The Desk Of Donald Trum...
# 2011-02-18 15:13:00  Check out my interview from MSNBC at http://on...
# 2011-02-17 22:48:00  Watch the latest From The Desk Of Donald Trump...
# 2011-02-17 16:06:00  I was speaking with Don Imus this morning.... ...
# 2011-02-16 20:59:00  THe Westminster Dog Show asked if I'd be inter...
# 2011-02-16 20:55:00  From The Desk Of Donald Trump- two new videos ...
# 2011-02-15 18:56:00  Check out ShouldTrumpRun....http://shouldtrump...
# 2011-02-15 14:38:00  FoxNewsInsider with comments on my speech at C...
# 2011-02-15 14:27:00  I was on CNN yesterday.....http://www.youtube....
# 2011-02-11 14:50:00  Watch my speech at CPAC in Washington DC yeste...
# 2011-02-10 18:29:00  It was great to appear on Piers Morgan Tonight...
# 2011-02-07 14:15:00  Be sure to watch Oprah today (4 pm on Channel ...
# 2011-01-31 14:25:00  Don't miss my Fabulous World of Golf now in it...
# 2011-01-31 14:04:00  Watch Melania on QVC this morning from 10 a.m....
# 2011-01-27 21:14:00  ...when they have no environmental restriction...
# 2011-01-27 21:13:00  THe people at shouldtrumprun.com have got it r...
# 2011-01-21 18:25:00  Don't miss my fabulous World of Golf now in it...
# 2011-01-21 17:20:00  Busy doing phoners this week with Neil Cavuto ...
# 2011-01-13 16:14:00  Don't forget to watch me tonight on Late Night...
# 2011-01-12 19:35:00  This afternoon I'll be speaking with Neil Cavu...
# 2011-01-12 15:28:00  Watch me on Late Night with Jimmy Fallon tomor...
#
#                      retweet_count  favorite_count  is_retweet  \
# created_at
# 2012-12-28 21:23:00              1               1       False
# 2012-12-28 21:22:00              3               2       False
# 2012-12-28 21:20:00           1038             458       False
# 2012-12-28 21:19:00             72              38       False
# 2012-12-28 21:13:00              2               1       False
# 2012-12-28 21:02:00            349             172       False
# 2012-12-28 20:45:00            569             153       False
# 2012-12-28 20:41:00              2               3       False
# 2012-12-28 20:36:00              0               1       False
# 2012-12-28 20:23:00            222             176       False
# 2012-12-28 20:09:00             56              17       False
# 2012-12-28 19:50:00            870             302       False
# 2012-12-28 19:45:00              0               0       False
# 2012-12-28 19:24:00            125              37       False
# 2012-12-28 19:01:00            178              68       False
# 2012-12-28 18:54:00              0               0       False
# 2012-12-28 18:40:00             29              11       False
# 2012-12-28 18:28:00             29              15       False
# 2012-12-28 18:13:00             55              27       False
# 2012-12-28 17:52:00            847             303       False
# 2012-12-28 17:48:00            213              98       False
# 2012-12-28 16:30:00             10               3       False
# 2012-12-28 16:13:00              0               0       False
# 2012-12-28 16:11:00              4               4       False
# 2012-12-28 16:09:00              0               1       False
# 2012-12-28 16:08:00              0               0       False
# 2012-12-28 16:04:00              1               1       False
# 2012-12-28 16:03:00              0               0       False
# 2012-12-28 16:02:00              0               0       False
# 2012-12-28 16:01:00              0               0       False
# ...                            ...             ...         ...
# 2011-03-07 19:01:00            102              20       False
# 2011-03-04 15:12:00             38               9       False
# 2011-03-03 14:52:00             68              17       False
# 2011-03-02 15:47:00             67              17       False
# 2011-03-02 00:02:00             49              16       False
# 2011-02-28 21:53:00             47              20       False
# 2011-02-28 17:42:00             64               9       False
# 2011-02-28 17:36:00             93              19       False
# 2011-02-23 21:43:00             56              18       False
# 2011-02-22 19:32:00             68              31       False
# 2011-02-18 15:13:00             70              21       False
# 2011-02-17 22:48:00             63              22       False
# 2011-02-17 16:06:00             23               8       False
# 2011-02-16 20:59:00            241             340       False
# 2011-02-16 20:55:00             27              12       False
# 2011-02-15 18:56:00             96              25       False
# 2011-02-15 14:38:00             29              11       False
# 2011-02-15 14:27:00             31              12       False
# 2011-02-11 14:50:00            109              45       False
# 2011-02-10 18:29:00             82              57       False
# 2011-02-07 14:15:00             66              16       False
# 2011-01-31 14:25:00             41              11       False
# 2011-01-31 14:04:00             13               5       False
# 2011-01-27 21:14:00             74              21       False
# 2011-01-27 21:13:00             73              26       False
# 2011-01-21 18:25:00             45               9       False
# 2011-01-21 17:20:00             47              14       False
# 2011-01-13 16:14:00            188              40       False
# 2011-01-12 19:35:00             36               8       False
# 2011-01-12 15:28:00             80              18       False
#
#                                  id_str  tweet_hour  source_num
# created_at
# 2012-12-28 21:23:00  284771680499408896          21           1
# 2012-12-28 21:22:00  284771320418410496          21           1
# 2012-12-28 21:20:00  284770791126601728          21           1
# 2012-12-28 21:19:00  284770536779829248          21           1
# 2012-12-28 21:13:00  284769064302280704          21           1
# 2012-12-28 21:02:00  284766285177442304          21           1
# 2012-12-28 20:45:00  284761957670727681          20           1
# 2012-12-28 20:41:00  284760895064784896          20           1
# 2012-12-28 20:36:00  284759862976581632          20           1
# 2012-12-28 20:23:00  284756552445997056          20           1
# 2012-12-28 20:09:00  284753032640593921          20           1
# 2012-12-28 19:50:00  284748270494961665          19           1
# 2012-12-28 19:45:00  284746928388980737          19           1
# 2012-12-28 19:24:00  284741754018754560          19           1
# 2012-12-28 19:01:00  284735836258451456          19           1
# 2012-12-28 18:54:00  284734145987485696          18           1
# 2012-12-28 18:40:00  284730512558403584          18           1
# 2012-12-28 18:28:00  284727564394700801          18           1
# 2012-12-28 18:13:00  284723815148302336          18           1
# 2012-12-28 17:52:00  284718429011849216          17           1
# 2012-12-28 17:48:00  284717566444830720          17           1
# 2012-12-28 16:30:00  284697774006599681          16           1
# 2012-12-28 16:13:00  284693649512607744          16           1
# 2012-12-28 16:11:00  284693175350722560          16           1
# 2012-12-28 16:09:00  284692657337430016          16           1
# 2012-12-28 16:08:00  284692240239058944          16           1
# 2012-12-28 16:04:00  284691303592259585          16           1
# 2012-12-28 16:03:00  284691091758923776          16           1
# 2012-12-28 16:02:00  284690769502162946          16           1
# 2012-12-28 16:01:00  284690429998419968          16           1
# ...                                 ...         ...         ...
# 2011-03-07 19:01:00   44835120405942272          19           1
# 2011-03-04 15:12:00   43690210873180160          15           1
# 2011-03-03 14:52:00   43322777758990336          14           1
# 2011-03-02 15:47:00   42974429189390336          15           1
# 2011-03-02 00:02:00   42736468908707840           0           1
# 2011-02-28 21:53:00   42341540923838464          21           1
# 2011-02-28 17:42:00   42278544969179136          17           1
# 2011-02-28 17:36:00   42276947971153920          17           1
# 2011-02-23 21:43:00   40527238277373953          21           1
# 2011-02-22 19:32:00   40131742803169280          19           1
# 2011-02-18 15:13:00   38617101547610112          15           1
# 2011-02-17 22:48:00   38369281221730304          22           1
# 2011-02-17 16:06:00   38268170745675776          16           1
# 2011-02-16 20:59:00   37979493029122048          20           1
# 2011-02-16 20:55:00   37978297749078016          20           1
# 2011-02-15 18:56:00   37585993838108672          18           1
# 2011-02-15 14:38:00   37521181040975872          14           1
# 2011-02-15 14:27:00   37518249373470720          14           1
# 2011-02-11 14:50:00   36074560650481664          14           1
# 2011-02-10 18:29:00   35767358031134720          18           1
# 2011-02-07 14:15:00   34616290815512576          14           1
# 2011-01-31 14:25:00   32082026404253698          14           1
# 2011-01-31 14:04:00   32076638262919169          14           1
# 2011-01-27 21:14:00   30735461429288960          21           1
# 2011-01-27 21:13:00   30735120168128512          21           1
# 2011-01-21 18:25:00   28518601644310528          18           1
# 2011-01-21 17:20:00   28502098983260160          17           1
# 2011-01-13 16:14:00   25586441258012672          16           1
# 2011-01-12 19:35:00   25274587486879745          19           1
# 2011-01-12 15:28:00   25212533853913088          15           1
#
# [32959 rows x 8 columns]

# %%
#Convert Source_num to dummy variables

dummy_trumptweets = pd.get_dummies(trumptweets, columns=['source_num']).drop('source_num_0', axis=1)

# %%
# Rename Dummy variable columns

dummy_trumptweets.rename(columns={'source_num_1': 'src_web_client',
                                  'source_num_2': 'src_iphone',
                                  'source_num_3': 'src_tweetdeck',
                                  'source_num_4': 'src_twitlonger',
                                  'source_num_5': 'src_instagram',
                                  'source_num_6': 'src_mediastudio',
                                  'source_num_7': 'src_facebook',
                                  'source_num_8': 'src_bberry',
                                  'source_num_9': 'src_twitter_ads',
                                  'source_num_10': 'src_mobilewebm5',
                                  'source_num_11': 'src_ipad',
                                  'source_num_12': 'src_twitlonger',
                                  'source_num_13': 'src_qanda',
                                  'source_num_14': 'src_vine',
                                  'source_num_15': 'src_periscope',
                                  'source_num_16': 'src_neatly_bberry',
                                  'source_num_17': 'src_mirror_ipad',
                                  'source_num_18': 'src_forwebsites'}, 
                                  inplace=True)

# %%
#Create new column, engagement, that summs retweet and favorite counts.  This will become my target y

dummy_trumptweets.loc[:, 'engagement'] = (dummy_trumptweets.loc[:, 'retweet_count'] +
                                          dummy_trumptweets.loc[:, 'favorite_count'])

# %%
# Do something with the tweet_hour column

# %%
# Convert hours to morning, afternoon, evening, latenight dummy variables.  Timestamp column is in GMT, so converting daytime hours to EST
# Default is morning


# EST 12-6pm is GMT 18-23
dummy_trumptweets.loc[:, 'is_afternoon'] = ((dummy_trumptweets.loc[:, 'tweet_hour'] >= 17) & (dummy_trumptweets.loc[:,'tweet_hour'] < 23)).astype(int)  

# EST 6pm-12am is 23 - 5
dummy_trumptweets.loc[:, 'is_evening'] = ((dummy_trumptweets.loc[:, 'tweet_hour'] >= 23) | (dummy_trumptweets.loc[:,'tweet_hour'] < 5)).astype(int)

# Late Night is EST 12am-5am is GMT 5-10
dummy_trumptweets.loc[:, 'is_latenight'] = ((dummy_trumptweets.loc[:, 'tweet_hour'] >= 5) & (dummy_trumptweets.loc[:,'tweet_hour'] < 10)).astype(int)

# %% [markdown]
# # Analysis and Visualizations

# %%
#describe all

dummy_trumptweets.describe(include='all')
# Out:
#                      source                       text  retweet_count  \
# count                 32959                      32959   32959.000000
# unique                   19                      32823            NaN
# top     Twitter for Android  MAKE AMERICA GREAT AGAIN!            NaN
# freq                  14545                         17            NaN
# mean                    NaN                        NaN    2956.526594
# std                     NaN                        NaN    7952.830522
# min                     NaN                        NaN       0.000000
# 25%                     NaN                        NaN      17.000000
# 50%                     NaN                        NaN     122.000000
# 75%                     NaN                        NaN    1377.000000
# max                     NaN                        NaN  369530.000000
#
#         favorite_count is_retweet        id_str    tweet_hour  src_web_client  \
# count     32959.000000      32959  3.295900e+04  32959.000000    32959.000000
# unique             NaN          2           NaN           NaN             NaN
# top                NaN      False           NaN           NaN             NaN
# freq               NaN      32428           NaN           NaN             NaN
# mean       9935.596620        NaN  5.147600e+17     13.078613        0.363421
# std       27812.355376        NaN  2.068257e+17      7.066306        0.480992
# min           0.000000        NaN  2.521253e+16      0.000000        0.000000
# 25%          21.000000        NaN  3.384114e+17      8.000000        0.000000
# 50%          73.000000        NaN  5.192658e+17     15.000000        0.000000
# 75%        2325.000000        NaN  6.626930e+17     19.000000        1.000000
# max      633253.000000        NaN  9.714098e+17     23.000000        1.000000
#
#           src_iphone  src_tweetdeck      ...        src_mobilewebm5  \
# count   32959.000000   32959.000000      ...           32959.000000
# unique           NaN            NaN      ...                    NaN
# top              NaN            NaN      ...                    NaN
# freq             NaN            NaN      ...                    NaN
# mean        0.146394       0.014564      ...               0.001699
# std         0.353506       0.119799      ...               0.041185
# min         0.000000       0.000000      ...               0.000000
# 25%         0.000000       0.000000      ...               0.000000
# 50%         0.000000       0.000000      ...               0.000000
# 75%         0.000000       0.000000      ...               0.000000
# max         1.000000       1.000000      ...               1.000000
#
#             src_ipad  src_twitlonger     src_qanda      src_vine  \
# count   32959.000000    32959.000000  32959.000000  32959.000000
# unique           NaN             NaN           NaN           NaN
# top              NaN             NaN           NaN           NaN
# freq             NaN             NaN           NaN           NaN
# mean        0.001547        0.000698      0.000303      0.000303
# std         0.039307        0.026408      0.017416      0.017416
# min         0.000000        0.000000      0.000000      0.000000
# 25%         0.000000        0.000000      0.000000      0.000000
# 50%         0.000000        0.000000      0.000000      0.000000
# 75%         0.000000        0.000000      0.000000      0.000000
# max         1.000000        1.000000      1.000000      1.000000
#
#         src_periscope  src_neatly_bberry  src_mirror_ipad  src_forwebsites  \
# count    32959.000000       32959.000000     32959.000000     32959.000000
# unique            NaN                NaN              NaN              NaN
# top               NaN                NaN              NaN              NaN
# freq              NaN                NaN              NaN              NaN
# mean         0.000212           0.000152         0.000030         0.000030
# std          0.014572           0.012316         0.005508         0.005508
# min          0.000000           0.000000         0.000000         0.000000
# 25%          0.000000           0.000000         0.000000         0.000000
# 50%          0.000000           0.000000         0.000000         0.000000
# 75%          0.000000           0.000000         0.000000         0.000000
# max          1.000000           1.000000         1.000000         1.000000
#
#            engagement
# count    32959.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean     12892.123214
# std      35192.481328
# min          0.000000
# 25%         45.000000
# 50%        211.000000
# 75%       4208.500000
# max     974628.000000
#
# [11 rows x 26 columns]

# %%
#boxplot of favorite_count

dummy_trumptweets.loc[:,'engagement'].plot(kind='box')

# %%
#Histogram of favorite count

dummy_trumptweets.loc[:, 'engagement'].hist(bins=40)

# %%
#Histogram of tweet_hour 

dummy_trumptweets.loc[:, 'tweet_hour'].hist(bins=24)

# %%
feature_cols = ['is_retweet', 
                'tweet_hour', 
                'src_iphone', 
                'src_web_client']

# %%
sns.pairplot(dummy_trumptweets,
            x_vars=feature_cols,
            y_vars='engagement',
            kind='reg',
            plot_kws={'scatter_kws': {'s':1, 'alpha':.3},
                      'line_kws': {'color':'red'}
                     }
            );

# %%
#Insert Correlation Matrix with HeatMap

sns.heatmap(dummy_trumptweets.corr(),
            vmin=-1,
            vmax = 1,
            cmap = sns.diverging_palette(220, 10, n=21),
            );

# %%
# Review Scatter plots

y = dummy_trumptweets.loc[:, 'engagement']

for var in feature_cols:
    print(var)
    x = dummy_trumptweets.loc[:, var]
    plt.scatter(x, y)
    plt.show()
# Out:
# is_retweet
# tweet_hour
# src_iphone
# src_web_client

# %% [markdown]
# # Linear Regression

# %%
#Create new column, engagement, that summs retweet and favorite counts.  This will become my target y

dummy_trumptweets.loc[:, 'engagement'] = (dummy_trumptweets.loc[:, 'retweet_count'] + 
                                          dummy_trumptweets.loc[:, 'favorite_count'])

# %%
feature_cols = ['is_retweet', 
                'tweet_hour', 
                'src_iphone', 
                'src_web_client']

# %%
X = dummy_trumptweets.loc[:, feature_cols]
y = dummy_trumptweets.loc[:, 'engagement']

# %%
#Split Train and Test

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# model on the training set of data

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# predict on the test set for X

y_pred = lr.predict(X_test)

# %%
# compare predicted results against the test set

#print(metrics.mean_squared_error(y_train, lr.predict(X_train)))

print(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 836952366.544

# %%
#Create Benchmark of Mean Values

y_pred_null = np.ones(y_test.shape) * y_train.mean()

#compare y_test against the y_means
metrics.mean_squared_error(y_test, y_pred_null)
# Out:
# 1219993179.7611389

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# 6457.82061084
# [-46284.75295119    122.05877993  54059.24509951  -6545.70048177]
